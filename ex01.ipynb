# %% [markdown]
# <a href="https://colab.research.google.com/github/Seong-heum/kics2021/blob/main/ex01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EX. 01
# [Colab.] https://colab.research.google.com/drive/1nRaEBVNTzxDLjRyc4OU3-kXpunkd-Cll#scrollTo=Uz2-Y9vEA8PU

# %% [markdown]
# # 1-1

# %%
# 설치 버전 확인
import cv2 as cv
print(cv.__version__)
print(cv.getBuildInformation())
# Out:
# 4.1.2
#
# General configuration for OpenCV 4.1.2 =====================================
#   Version control:               4.1.2
#
#   Extra modules:
#     Location (extra):            /io/opencv_contrib/modules
#     Version control (extra):     4.1.2
#
#   Platform:
#     Timestamp:                   2019-11-22T00:46:11Z
#     Host:                        Linux 4.15.0-1028-gcp x86_64
#     CMake:                       3.9.0
#     CMake generator:             Unix Makefiles
#     CMake build tool:            /usr/bin/gmake
#     Configuration:               Release
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3
#       requested:                 SSE3
#     Dispatched code generation:  SSE4_1 SSE4_2 FP16 AVX
#       requested:                 SSE4_1 SSE4_2 AVX FP16 AVX2 AVX512_SKX
#       SSE4_1 (14 files):         + SSSE3 SSE4_1
#       SSE4_2 (1 files):          + SSSE3 SSE4_1 POPCNT SSE4_2
# ...

# %%
# 파일 받기
# !wget https://www.dropbox.com/s/oeyudt0x0f6hv5q/apple.jpg?dl=0 -O apple.jpg
# Out:
# --2021-05-24 14:44:06--  https://www.dropbox.com/s/oeyudt0x0f6hv5q/apple.jpg?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/oeyudt0x0f6hv5q/apple.jpg [following]
# --2021-05-24 14:44:06--  https://www.dropbox.com/s/raw/oeyudt0x0f6hv5q/apple.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca7c766aa080e2441092e659e8b.dl.dropboxusercontent.com/cd/0/inline/BPGTvt2bMZnLFbUqeNGjKLBNxs6WEd2H8O3QkERcHf-WVt3V1I8H_dM5vFWvBWRSt8vW1RFUIFoXfMHH6P92cUDbbeSkLrtZbv8aJaOk__YaxoE53EBFmXQKwtrm4Oljxvr6G_Gw-xJrRheQAxXTcxx7/file# [following]
# ...

# %%
from google.colab.patches import cv2_imshow

image = cv.imread("apple.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDBA47FF50>

# %%
x, y = 200, 300
pixel_value = image[y, x]
print(x, y, pixel_value)

image[y, x] = [255, 255, 255]
cv2_imshow(image)
# Out:
# 200 300 [0 0 0]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDB5CDC110>

# %%
cv.drawMarker(image, (x, y), (255, 0, 0), 0)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDB5CFD6D0>

# %% [markdown]
# # 1-2

# %%
import cv2 as cv
import numpy as np

# 상수 파라메터
FILTER_SIZE = 5
FILTER_SIGMA = 1

inp = cv.imread("apple.jpg")

# %%
# Averaging
def filter_averaging( inp ):
    filter = np.ones((FILTER_SIZE,FILTER_SIZE)) / (FILTER_SIZE*FILTER_SIZE)
    print(filter)

    out = cv.filter2D(inp, -1, filter)
    return out

out_average  = filter_averaging( inp )
cv2_imshow(out_average)
# Out:
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDB5CBCFD0>

# %%
#FILTER_SIZE = 25
#FILTER_SIGMA = 50

# %%
# Gaussian filter
def filter_gaussian(inp):
    out = cv.GaussianBlur(inp, (FILTER_SIZE, FILTER_SIZE), FILTER_SIGMA)
    return out

out_gaussian  = filter_gaussian( inp )
cv2_imshow(out_gaussian)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDB5CDA9D0>

# %%
# Bilateral filter
def filter_bilateral(inp):
    out = cv.bilateralFilter(inp, FILTER_SIZE, FILTER_SIGMA, FILTER_SIGMA)
    return out

out_bilateral  = filter_bilateral( inp )
cv2_imshow(out_bilateral)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7EFDB5CDA210>
